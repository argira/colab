# %%
import numpy                 as np
import pandas                as pd
import matplotlib.pyplot     as plt
import seaborn               as sns
import sklearn.metrics       as Metrics
import pandas                as pd
import matplotlib.pyplot     as plt


import folium  #needed for interactive map
from folium.plugins import HeatMap

from   collections           import Counter
from   sklearn               import preprocessing
from   datetime              import datetime
from   collections           import Counter
from   math                  import exp
from   sklearn.linear_model  import LinearRegression as LinReg
from   sklearn.metrics       import mean_absolute_error
from   sklearn.metrics       import median_absolute_error
from   sklearn.metrics       import r2_score

# %matplotlib inline
sns.set()

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels
from scipy import stats
from pingouin import pairwise_ttests #this is for performing the pairwise tests
import warnings
warnings.filterwarnings("ignore")  # Suppress all warnings

# %%
df = pd.read_csv("https://raw.githubusercontent.com/softwareguru/salarios-notebook/main/answers-2021.csv", index_col=0)

# %%
df.head()
# Out:
#                   created  salarymx  salaryusd  extramx  extrausd  variation  \
# id
# 2675  2020-11-20 04:44:40     30000          0        0         0         10
# 2676  2020-11-20 19:05:13         0          0        0         0          0
# 2677  2020-11-20 19:05:25     40000          0   500000         0         35
# 2678  2020-11-20 19:07:41     18000          0    20000         0         50
# 2679  2020-11-20 19:07:42     18000          0    20000         0         50
#
#       english_num                                      english_label  age  \
# id
# 2675            4  Avanzado: Puedo conversar y escribir sin probl...   30
# 2676            4  Avanzado: Puedo conversar y escribir sin probl...   37
# 2677            3  Profesional: Puedo interactuar profesionalment...   30
# 2678            0                                    Ninguno (ILR 0)   23
# 2679            0                                    Ninguno (ILR 0)   23
#
#       experience  ...  ben_healthmajor ben_healthminor ben_lifeins  \
# id                ...
# 2675           5  ...              NaN             NaN         NaN
# 2676          12  ...                Y             NaN           Y
# 2677           6  ...                Y             NaN           Y
# 2678           2  ...                Y               Y           Y
# 2679           2  ...                Y               Y           Y
#
#      ben_cafeteria ben_cellphone ben_vouchers covid_remoto covid_salario  \
# id
# 2675           NaN           NaN          NaN          NaN           NaN
# 2676             Y           NaN          NaN       remote         igual
# 2677           NaN           NaN            Y       remote         mejor
# 2678           NaN           NaN          NaN       remote         igual
# 2679           NaN           NaN          NaN       remote         igual
#
#      covid_carga  covid_apoyo
# id
# 2675         NaN          NaN
# 2676   aumentado  computadora
# 2677   aumentado  computadora
# 2678   aumentado  computadora
# 2679   aumentado  computadora
#
# [5 rows x 161 columns]

# %%
df.columns
# Out:
# Index(['created', 'salarymx', 'salaryusd', 'extramx', 'extrausd', 'variation',
#        'english_num', 'english_label', 'age', 'experience',
#        ...
#        'ben_healthmajor', 'ben_healthminor', 'ben_lifeins', 'ben_cafeteria',
#        'ben_cellphone', 'ben_vouchers', 'covid_remoto', 'covid_salario',
#        'covid_carga', 'covid_apoyo'],
#       dtype='object', length=161)

# %%
df1=df[['remote','salarymx', 'age', 'experience','seniority','emptype','gender','edutype','english_label','city','profile','orgtype','education','covid_salario',
       'covid_carga', 'covid_apoyo' ]]

# %%
df2=df.drop(columns=('salarymx', 'age', 'experience','seniority','emptype','gender','edutype','english_label','city','profile','orgtype','education'))

# %%
df1
# Out:
#       salarymx  age  experience  seniority     emptype  gender      edutype  \
# id
# 2675     30000   30           5          1      nomina  hombre      escuela
# 2676         0   37          12          3      nomina  hombre      escuela
# 2677     40000   30           6          2      nomina  hombre  autodidacta
# 2678     18000   23           2          2      nomina      nb      escuela
# 2679     18000   23           2          2      nomina      nb      escuela
# ...        ...  ...         ...        ...         ...     ...          ...
# 4288     41000   41          16          4  honorarios  hombre      escuela
# 4289     36250   32           8          1     hibrido  hombre      escuela
# 4290     36250   32           8          1     hibrido  hombre      escuela
# 4291     24000   26           3          0  honorarios   mujer  autodidacta
# 4292     10000   30           2          2      nomina  hombre      escuela
#
#                                           english_label              city  \
# id
# 2675  Avanzado: Puedo conversar y escribir sin probl...              CDMX
# 2676  Avanzado: Puedo conversar y escribir sin probl...              CDMX
# 2677  Profesional: Puedo interactuar profesionalment...            Mérida
# 2678                                    Ninguno (ILR 0)              CDMX
# 2679                                    Ninguno (ILR 0)              CDMX
# ...                                                 ...               ...
# 4288    Elemental: Sé lo básico para sobrevivir (ILR 1)  Estado de méxico
# 4289    Elemental: Sé lo básico para sobrevivir (ILR 1)            Mexico
# 4290    Elemental: Sé lo básico para sobrevivir (ILR 1)            Mexico
# 4291  Limitado: Me doy a entender pero con errores d...          Veracruz
# 4292    Elemental: Sé lo básico para sobrevivir (ILR 1)      Tlalnepantla
#
#          profile     orgtype    education
# id
# 2675   directivo  itservices      pasante
# 2676       godin        corp     maestria
# 2677       godin     startup  universidad
# 2678       godin  itservices      pasante
# 2679       godin  itservices      pasante
# ...          ...         ...          ...
# 4288       godin  itservices  universidad
# 4289       godin  itservices      pasante
# 4290       godin  itservices      pasante
# 4291       godin  itservices      tecnica
# 4292  estudiante  itservices      tecnica
#
# [1618 rows x 12 columns]

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='edutype',y='salarymx',hue='gender',data=df)
plt.title('Diferencia de Salario en genero por tipo de educacion')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='profile',y='salarymx', palette = 'YlGnBu',hue='gender'
            ,data=df1)
plt.title('Los Hombres tienen un Salario superior en cada perfil de puesto \n', fontsize=16)
_ = plt.xlabel('Perfil de puesto', fontsize=16)
_ = plt.ylabel('Salario en Pesos', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='profile',y='salarymx',hue='gender',data=df)
plt.title('Diferencia de Salario en genero por tipo de educacion')
plt.show()

# %% [markdown]
# Parece que la clasificacion godin (Imagino tiene que ver con godinez, no esta claro) tienen el mayor numero de valores atipicos.

# %%
#Identificamos los limites de datos atipicos

salarymx = df1['salarymx']
iqr = salarymx.quantile(q=.75) - salarymx.quantile(q=0.25)

lower_outlier = salarymx.quantile(q=0.25) - (1.5*iqr)
upper_outlier = salarymx.quantile(q=0.75) + (1.5*iqr)

print('lower_outlier is ',lower_outlier , 'upper_outlier is',upper_outlier)
# Out:
# lower_outlier is  -40000.0 upper_outlier is 120000.0

# %%
#REmovemos los datos atipicos
df1=df1[df1['salarymx'] < 120000]
df1=df1[df1['salarymx']!=0]

# %%
plt.figure(figsize=(8,6))
sns.distplot(df1['salarymx'])
plt.title('Distribucion de Salarios', fontsize = 16)

# Adding labels
_ = plt.xlabel('Salario en Mexico', fontsize=16)
_ = plt.ylabel('Densidad', fontsize=16)

plt.show()

# %%
_ = sns.displot(df1, x='salarymx', hue='gender', kind="kde", palette='YlGnBu',fill=True)
_.fig.set_size_inches(10,6)
plt.title("Distribucion de Salario por Genero", fontsize=18)
plt.xlabel('Salario en Mexico', fontsize=18)
plt.ylabel('Densidad', fontsize=18)
# Out:
# Text(18.072256249999995, 0.5, 'Densidad')

# %%
df1.groupby(['gender'])['salarymx'].mean()
# Out:
# gender
# hombre    45268.158570
# mujer     34044.768786
# nb        36995.454545
# Name: salarymx, dtype: float64

# %%
#Vemos la tabla nuevamente sin los resultados atipicos
plt.figure(figsize=(15,6))
sns.boxplot(x='edutype',y='salarymx',hue='gender',data=df1)
plt.title('Diferencia de Salario en genero por tipo de educacion')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='profile',y='salarymx',hue='gender',data=df1)
plt.title('Diferencia de Salario en genero por tipo de educacion')
plt.show()

# %% [markdown]
# Parece que en el campo de independientes y emprendedores, mayormente hombres. Y es aqui donde hay mayor diferencia entre el salario de hombres y mujeres, asi como emprendedores. Seria interesante saber si son las mujeres que se valuan menos cuando proponen sus servicios o si la industria ofrece manos si eres mujer.

# %%
pl = sns.countplot(x="profile", hue= "gender", data= df1)
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title(" Distribucion de hombres y mujeres en los distintos profile", fontsize=20, verticalalignment='bottom');

# %%
#separamos el profile godin para ver la distribucion de los otros perfiles
df2=df1[df1['profile']!='godin']
pl = sns.countplot(x="profile", hue= "gender", data= df2)
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title(" Distribucion de hombres y mujeres en los distintos profile", fontsize=20, verticalalignment='bottom');

# %% [markdown]
# De los encuestados, habia una poblacion mayor de hombres en todas los perfiles, a excepcion de docentes. Cuando vemos la distribucion de salario, hay que ver si la difrencia es estadisticament significativa o no entre los salarios de hombres y mujeres.

# %%
#separamos el profile godin para ver la distribucion de este.
df2=df1[df1['profile']=='godin']
pl = sns.countplot(x="profile", hue= "gender", data= df2)
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title(" Distribucion de hombres y mujeres en los distintos profile", fontsize=20, verticalalignment='bottom');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='profile',y='salarymx',hue='edutype',data=df1, palette='YlGnBu')
plt.title('Diferencia de Salario por perfil en base donde aprendieron a Programar')
plt.show()

# %% [markdown]
# Podemos observar que las diferencias en Salario estan mas ligadas a el perfil que a el lugar donde recibieron la educacion.

# %%
def highlight_high_p(s):
    #Highlight the values where p corrected value is higher than .05
    is_high = s > 0.05
    return ['background-color:orange' if v else "" for v in is_high]

# %%
#df1['subgroup_dis'] = df1['profile'] + df1['gender']  #Nueva columna con genero por perfil.
#df1=[df1[df1['salarymx']!=0]]
pairwise_results = pairwise_ttests(dv="salarymx", between = ['profile'], data=df1)
s=pairwise_results.style.apply(highlight_high_p, subset=['p-corr'])

# %%
#Que numero de poblacion tenemos por perfil
pl = sns.countplot(x="edutype", data= df1)
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title(" Distribucion por typo de educacion", fontsize=20, verticalalignment='bottom');

# %%
#Que numero de poblacion tenemos por perfil
pl = sns.countplot(x="education", data= df1)
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title(" Distribucion por typo de educacion", fontsize=20, verticalalignment='bottom');

# %%
#Que numero de poblacion tenemos por perfil
pl = sns.countplot(x="seniority", data= df1)
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title(" Distribucion por seniority", fontsize=20, verticalalignment='bottom');

# %%
sns.lmplot(x="experience", y="salarymx"#, hue="Disadvantaged"
           , palette="plasma",
           col="profile", #row="sex,"
           data=df1, col_wrap=2, height=5);

# %%
sns.lmplot(x = 'seniority', y = 'salarymx', data = df1, scatter_kws = {'color': (174/255,199/255,14/255)})
plt.title("Salario vs. Seniority", fontsize=20, verticalalignment='bottom')
plt.axhline(df['salarymx'].mean(), ls='--',color = 'b')
plt.xlabel("Seniority")
plt.ylabel("Salario Mexico");

# %%
sns.lmplot(x = 'experience', y = 'salarymx', data = df1, scatter_kws = {'color': (174/255,199/255,14/255)})
plt.title("Salario vs. Experiencia", fontsize=20, verticalalignment='bottom')
plt.axhline(df['salarymx'].mean(), ls='--',color = 'b')
plt.xlabel("Experiencia")
plt.ylabel("Salario Mexico");

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='experience', y='salarymx', hue='edutype', #style='edutype',
                data=df1)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='experience', y='salarymx', hue='profile', #style='edutype',
                data=df1)
plt.title('A mayor experiencia se ve una relación directa de mayor salario y la posición.\n Sin embargo a partir de 25 años de experiencia el nivel de salario empieza a disminuir', fontsize=16)
_ = plt.xlabel('Años de Experiencia', fontsize=16)
_ = plt.ylabel('Salario en Pesos', fontsize=16)
plt.show()

# %%
plt.figure()
sns.heatmap(df1.corr(),annot=True, linewidth=0.5,fmt='.1f')
plt.show()

# %%
#Veamos por separado cada perfil para ver si la edad continua siendo un factor en todos en relacion a la edad.
g = sns.FacetGrid(df1, row='profile', #hue="Disadvantaged", 
                  margin_titles=True, height=6, aspect=2, palette="plasma")

g.map(sns.regplot,'salarymx', 'age',marker="x")

#_=g.set(xlim=(8800, 17500), 
# ylim=(2300, 2700))
_=g.add_legend()

# %% [markdown]
# Directivo - La edad no parece tener mucho impacto ya que hay salarios bajos y altos a distintas edades, pero empezamos a ver a partir de los 50 los salarios bajan drasticamente en todas las categorias.
# Para Independientes y emprendedores parece haber una relacion en cuanto a la edad muy positiva, despues de los 50 baja, aunque la muestra es pequeña y parece bajar en menor grado que en otros perfiles.
# En cuanto al genero, en todos los perfiles a excepcion de godin y emprendedor, las mujeres parece tener una baja relacion con salarios no cambiando con a edad. Seria interesante saber a que se debe

# %%
#Veamos si los tipos de estudio y perfiles estan relacionados o son independientes
cross=pd.crosstab(df1['profile'], df1['edutype'])
cross
# Out:
# edutype        autodidacta  bootcamp  escuela  online  trabajo
# profile
# directivo               22         0       48       6       11
# docente                  5         1       33       0        1
# emprendedor             15         0       18       1        8
# estudiante               2         1       18       8        1
# godin                  179        46      846      84      160
# independiente           18         2       22       4        6
# otro                    11         2       15       5        6

# %%
dis_perfil_prop = round(cross.div(cross.sum(axis=1), axis=0)*100,2)
dis_perfil_prop
# Out:
# edutype        autodidacta  bootcamp  escuela  online  trabajo
# profile
# directivo            25.29      0.00    55.17    6.90    12.64
# docente              12.50      2.50    82.50    0.00     2.50
# emprendedor          35.71      0.00    42.86    2.38    19.05
# estudiante            6.67      3.33    60.00   26.67     3.33
# godin                13.61      3.50    64.33    6.39    12.17
# independiente        34.62      3.85    42.31    7.69    11.54
# otro                 28.21      5.13    38.46   12.82    15.38

# %%
plt_prop = dis_perfil_prop.plot(kind='bar', stacked = True, width = 1,colormap='rocket')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('Porcentaje por tipo de educacion en los distintos perfiles ', fontsize=18)
_ = plt.xlabel('perfil', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
g, p, dof, expctd = chi2_contingency(cross)
print("Valor P de  Chi cuadrada para Tipo de Educacion vs. Perfil =", p)
# Out:
# Valor P de  Chi cuadrada para Tipo de Educacion vs. Perfil = 4.870024345040851e-09

# %% [markdown]
# vemos que el tipo de educacion y el perfil no son variables independientes, ya que por ejemplo los docentes son mayormente educados en la escuela y los emprendedores o independientes parece tener mas educacion autodidacta.

# %%
#Nivel de ingles es independiente de perfil
crosse=pd.crosstab(df1['profile'], df1['english_label'])
cross
# Out:
# english_label  Avanzado: Puedo conversar y escribir sin problemas sobre cualquier tema (ILR 4)  \
# profile
# directivo                                                     27
# docente                                                        6
# emprendedor                                                   11
# estudiante                                                     4
# godin                                                        326
# independiente                                                 19
# otro                                                           7
#
# english_label  Elemental: Sé lo básico para sobrevivir (ILR 1)  \
# profile
# directivo                                                    6
# docente                                                      2
# emprendedor                                                  4
# estudiante                                                   5
# godin                                                      135
# independiente                                                1
# otro                                                         3
#
# english_label  Limitado: Me doy a entender pero con errores de gramática (ILR 2)  \
# profile
# directivo                                                     17
# docente                                                       12
# emprendedor                                                   16
# estudiante                                                    12
# godin                                                        376
# independiente                                                 21
# otro                                                          14
#
# english_label  Nativo o bilingue (ILR 5)  Ninguno (ILR 0)  \
# profile
# directivo                             10                0
# docente                                0                0
# emprendedor                            0                0
# estudiante                             5                0
# godin                                 53                8
# independiente                          1                0
# otro                                   2                1
#
# english_label  Profesional: Puedo interactuar profesionalmente con colegas y clientes (ILR 3)
# profile
# directivo                                                     27
# docente                                                       20
# emprendedor                                                   11
# estudiante                                                     4
# godin                                                        417
# independiente                                                 10
# otro                                                          12

# %%
dis_english_prop = round(crosse.div(crosse.sum(axis=1), axis=0)*100,2)
dis_english_prop
# Out:
# english_label  Avanzado: Puedo conversar y escribir sin problemas sobre cualquier tema (ILR 4)  \
# profile
# directivo                                                  31.03
# docente                                                    15.00
# emprendedor                                                26.19
# estudiante                                                 13.33
# godin                                                      24.79
# independiente                                              36.54
# otro                                                       17.95
#
# english_label  Elemental: Sé lo básico para sobrevivir (ILR 1)  \
# profile
# directivo                                                 6.90
# docente                                                   5.00
# emprendedor                                               9.52
# estudiante                                               16.67
# godin                                                    10.27
# independiente                                             1.92
# otro                                                      7.69
#
# english_label  Limitado: Me doy a entender pero con errores de gramática (ILR 2)  \
# profile
# directivo                                                  19.54
# docente                                                    30.00
# emprendedor                                                38.10
# estudiante                                                 40.00
# godin                                                      28.59
# independiente                                              40.38
# otro                                                       35.90
#
# english_label  Nativo o bilingue (ILR 5)  Ninguno (ILR 0)  \
# profile
# directivo                          11.49             0.00
# docente                             0.00             0.00
# emprendedor                         0.00             0.00
# estudiante                         16.67             0.00
# godin                               4.03             0.61
# independiente                       1.92             0.00
# otro                                5.13             2.56
#
# english_label  Profesional: Puedo interactuar profesionalmente con colegas y clientes (ILR 3)
# profile
# directivo                                                  31.03
# docente                                                    50.00
# emprendedor                                                26.19
# estudiante                                                 13.33
# godin                                                      31.71
# independiente                                              19.23
# otro                                                       30.77

# %%
plt_prop = dis_english_prop.plot(kind='bar', stacked = True, width = 1,colormap='rocket')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('Porcentaje por nivel de ingles en los distintos perfiles ', fontsize=18)
_ = plt.xlabel('perfil', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
g, p, dof, expctd = chi2_contingency(crosse)
print("Valor P de  Chi cuadrada para Ingles  vs. Perfil =", p)
# Out:
# Valor P de  Chi cuadrada para Ingles  vs. Perfil = 0.0004243239479789972

# %% [markdown]
# Al parecer las variables muestran dependencia entre el perfil y el nivel de ingles. Mayormente avanzados son los directivos, emprendedores e independientes

# %%
#Nivel de ingles es independiente de perfil
crossg=pd.crosstab(df1['profile'], df1['gender'])
crossg
# Out:
# gender         hombre  mujer  nb
# profile
# directivo          74     12   1
# docente            21     19   0
# emprendedor        38      4   0
# estudiante         16     14   0
# godin            1010    296   9
# independiente      42     10   0
# otro               30      8   1

# %%
dis_gender_prop = round(crossg.div(crossg.sum(axis=1), axis=0)*100,2)
dis_gender_prop
# Out:
# gender         hombre  mujer    nb
# profile
# directivo       85.06  13.79  1.15
# docente         52.50  47.50  0.00
# emprendedor     90.48   9.52  0.00
# estudiante      53.33  46.67  0.00
# godin           76.81  22.51  0.68
# independiente   80.77  19.23  0.00
# otro            76.92  20.51  2.56

# %%
plt_prop = dis_gender_prop.plot(kind='bar', stacked = True, width = 1,colormap='YlGnBu')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('Porcentaje de genero en cada perfil', fontsize=18)
_ = plt.xlabel('Perfil de Puesto', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
g, p, dof, expctd = chi2_contingency(crosse)
print("Valor P de  Chi cuadrada para Genero  vs. Perfil =", p)
# Out:
# Valor P de  Chi cuadrada para Genero  vs. Perfil = 0.0004243239479789972

# %% [markdown]
# Vemos que los perfiles y el genero no son independientes. Es en el area de educacion donde hay mas mujeres, en la encuesta realizada

# %%
crossgi=pd.crosstab(df1['english_label'], df1['profile'])
crossgi
# Out:
# profile                                             directivo  docente  \
# english_label
# Avanzado: Puedo conversar y escribir sin proble...         27        6
# Elemental: Sé lo básico para sobrevivir (ILR 1)             6        2
# Limitado: Me doy a entender pero con errores de...         17       13
# Nativo o bilingue (ILR 5)                                  10        0
# Ninguno (ILR 0)                                             0        0
# Profesional: Puedo interactuar profesionalmente...         27       20
#
# profile                                             emprendedor  estudiante  \
# english_label
# Avanzado: Puedo conversar y escribir sin proble...           11           4
# Elemental: Sé lo básico para sobrevivir (ILR 1)               4           6
# Limitado: Me doy a entender pero con errores de...           16          12
# Nativo o bilingue (ILR 5)                                     0           5
# Ninguno (ILR 0)                                               0           0
# Profesional: Puedo interactuar profesionalmente...           11           4
#
# profile                                             godin  independiente  otro
# english_label
# Avanzado: Puedo conversar y escribir sin proble...    326             19     7
# Elemental: Sé lo básico para sobrevivir (ILR 1)       139              1     3
# Limitado: Me doy a entender pero con errores de...    378             21    14
# Nativo o bilingue (ILR 5)                              54              1     2
# Ninguno (ILR 0)                                         8              0     1
# Profesional: Puedo interactuar profesionalmente...    421             10    12

# %%
dis_gendere_prop = round(crossgi.div(crossgi.sum(axis=0), axis=1)*100,2).T
dis_gendere_prop
# Out:
# english_label  Avanzado: Puedo conversar y escribir sin problemas sobre cualquier tema (ILR 4)  \
# profile
# directivo                                                  31.03
# docente                                                    14.63
# emprendedor                                                26.19
# estudiante                                                 12.90
# godin                                                      24.59
# independiente                                              36.54
# otro                                                       17.95
#
# english_label  Elemental: Sé lo básico para sobrevivir (ILR 1)  \
# profile
# directivo                                                 6.90
# docente                                                   4.88
# emprendedor                                               9.52
# estudiante                                               19.35
# godin                                                    10.48
# independiente                                             1.92
# otro                                                      7.69
#
# english_label  Limitado: Me doy a entender pero con errores de gramática (ILR 2)  \
# profile
# directivo                                                  19.54
# docente                                                    31.71
# emprendedor                                                38.10
# estudiante                                                 38.71
# godin                                                      28.51
# independiente                                              40.38
# otro                                                       35.90
#
# english_label  Nativo o bilingue (ILR 5)  Ninguno (ILR 0)  \
# profile
# directivo                          11.49             0.00
# docente                             0.00             0.00
# emprendedor                         0.00             0.00
# estudiante                         16.13             0.00
# godin                               4.07             0.60
# independiente                       1.92             0.00
# otro                                5.13             2.56
#
# english_label  Profesional: Puedo interactuar profesionalmente con colegas y clientes (ILR 3)
# profile
# directivo                                                  31.03
# docente                                                    48.78
# emprendedor                                                26.19
# estudiante                                                 12.90
# godin                                                      31.75
# independiente                                              19.23
# otro                                                       30.77

# %%
plt_prop = dis_gendere_prop.plot(kind='bar', stacked = True, width = 1,colormap='YlGnBu')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('Niveles de ingles presentes por perfil de puesto', fontsize=18)
_ = plt.xlabel('Nivel de Ingles', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
g, p, dof, expctd = chi2_contingency(crossgi)
print("Valor P de  Chi cuadrada para Genero  vs. Nivel de ingles =", p)
# Out:
# Valor P de  Chi cuadrada para Genero  vs. Nivel de ingles = 0.0003116610760688664

# %%
df_activity = df[[
'act_dba',
'act_req',
'act_arq',
'act_bi',
'act_cap',
'act_dsc',
'act_spi',
'act_cons',
'act_dir',
'act_doc',
'act_techwrite',
'act_devops',
'act_erp',
'act_deng',
'act_techsales',
'act_prog',
'act_front',
'act_pm',
'act_infosec',
'act_soporte',
'act_test',
'act_uxd',
'act_ventas',
'salarymx',
'gender',
'profile',
'education', 'edutype','remote']]

# %%
df_activity
# Out:
#      act_dba act_req act_arq act_bi act_cap act_dsc act_spi act_cons act_dir  \
# id
# 2675     NaN     NaN     NaN    NaN     NaN     NaN       Y      NaN     NaN
# 2676     NaN       Y       Y    NaN     NaN     NaN       Y      NaN       Y
# 2677     NaN     NaN     NaN      Y     NaN       Y     NaN      NaN     NaN
# 2678     NaN     NaN     NaN    NaN     NaN     NaN     NaN      NaN     NaN
# 2679     NaN     NaN     NaN    NaN     NaN     NaN     NaN      NaN     NaN
# ...      ...     ...     ...    ...     ...     ...     ...      ...     ...
# 4288     NaN     NaN     NaN      Y     NaN     NaN     NaN      NaN     NaN
# 4289     NaN     NaN     NaN    NaN     NaN     NaN     NaN      NaN     NaN
# 4290     NaN     NaN     NaN    NaN     NaN     NaN     NaN      NaN     NaN
# 4291     NaN     NaN     NaN    NaN     NaN     NaN     NaN      NaN     NaN
# 4292     NaN     NaN     NaN    NaN     NaN     NaN     NaN      NaN     NaN
#
#      act_doc  ... act_soporte act_test act_uxd act_ventas salarymx  gender  \
# id            ...
# 2675     NaN  ...         NaN      NaN     NaN        NaN    30000  hombre
# 2676     NaN  ...         NaN      NaN     NaN        NaN        0  hombre
# 2677     NaN  ...         NaN      NaN     NaN        NaN    40000  hombre
# 2678     NaN  ...         NaN      NaN     NaN        NaN    18000      nb
# 2679     NaN  ...         NaN      NaN     NaN        NaN    18000      nb
# ...      ...  ...         ...      ...     ...        ...      ...     ...
# 4288     NaN  ...         NaN      NaN     NaN        NaN    41000  hombre
# 4289     NaN  ...         NaN      NaN     NaN        NaN    36250  hombre
# 4290     NaN  ...         NaN      NaN     NaN        NaN    36250  hombre
# 4291     NaN  ...         NaN      NaN     NaN        NaN    24000   mujer
# 4292     NaN  ...         NaN      NaN     NaN          Y    10000  hombre
#
#          profile    education      edutype remote
# id
# 2675   directivo      pasante      escuela      Y
# 2676       godin     maestria      escuela      N
# 2677       godin  universidad  autodidacta      N
# 2678       godin      pasante      escuela      N
# 2679       godin      pasante      escuela      N
# ...          ...          ...          ...    ...
# 4288       godin  universidad      escuela      N
# 4289       godin      pasante      escuela      N
# 4290       godin      pasante      escuela      N
# 4291       godin      tecnica  autodidacta      N
# 4292  estudiante      tecnica      escuela      N
#
# [1618 rows x 29 columns]

# %%
#df_activity = df_activity.fillna(0)

# %%
#df_activity = df_activity.replace(['Y'], 1)

# %%
df_activity =df_activity[df_activity['salarymx'] < 120000]
df_activity=df_activity[df_activity['salarymx']!=0]

# %%
# Inicializamos nuestra lista maestra
item_list = []
# URL del catálogo
reader = pd.read_csv('https://raw.githubusercontent.com/softwareguru/salarios-notebook/main/activity_options.csv')
#reader = get_remote_csv_reader(url)

#for row in reader:
 #   item_key = "act_"+row['key']
  #  item_list.append([row['name'], df[(df[item_key]=="Y")]["salarymx"].count(), df[(df[item_key]=="Y")]["salarymx"].median(), df[(df[item_key]=="Y")]["salarymx"].mean(), df[(df[item_key]=="Y")]["salarymx"].std()])

# %%
#Melt the data to have each ethnicity 
DFactmelt = pd.melt(df_activity, id_vars=[
'gender',
'profile',
'education', 'salarymx','edutype','remote'], 
        value_vars=['act_dba',
'act_req',
'act_arq',
'act_bi',
'act_cap',
'act_dsc',
'act_spi',
'act_cons',
'act_dir',
'act_doc',
'act_techwrite',
'act_devops',
'act_erp',
'act_deng',
'act_techsales',
'act_prog',
'act_front',
'act_pm',
'act_infosec',
'act_soporte',
'act_test',
'act_uxd',
'act_ventas'])

# %%
DFactmelt
# Out:
#        gender     profile    education  salarymx      edutype remote  \
# 0      hombre   directivo      pasante     30000      escuela      Y
# 1      hombre       godin  universidad     40000  autodidacta      N
# 2          nb       godin      pasante     18000      escuela      N
# 3          nb       godin      pasante     18000      escuela      N
# 4      hombre   directivo     maestria     47000  autodidacta      N
# ...       ...         ...          ...       ...          ...    ...
# 33299  hombre       godin  universidad     41000      escuela      N
# 33300  hombre       godin      pasante     36250      escuela      N
# 33301  hombre       godin      pasante     36250      escuela      N
# 33302   mujer       godin      tecnica     24000  autodidacta      N
# 33303  hombre  estudiante      tecnica     10000      escuela      N
#
#          variable value
# 0         act_dba   NaN
# 1         act_dba   NaN
# 2         act_dba   NaN
# 3         act_dba   NaN
# 4         act_dba   NaN
# ...           ...   ...
# 33299  act_ventas   NaN
# 33300  act_ventas   NaN
# 33301  act_ventas   NaN
# 33302  act_ventas   NaN
# 33303  act_ventas     Y
#
# [33304 rows x 8 columns]

# %%
DFact =DFactmelt.dropna()

# %%
DFact['actividad']=DFact['variable'].str.slice(start=4, step=1)

# %%
DFact
# Out:
#        gender        profile    education  salarymx  edutype remote  \
# 6       mujer          godin      pasante      9000  escuela      N
# 9      hombre  independiente  universidad      4000  escuela      N
# 11     hombre          godin     maestria     45000  escuela      N
# 16     hombre          godin  universidad     25914  escuela      N
# 17     hombre          godin  universidad     25000  escuela      N
# ...       ...            ...          ...       ...      ...    ...
# 33027  hombre      directivo     posgrado     70000  escuela      N
# 33057   mujer          godin  universidad     30000  trabajo      N
# 33063  hombre    emprendedor  universidad     80000  escuela      N
# 33114  hombre      directivo     maestria     55000  escuela      N
# 33303  hombre     estudiante      tecnica     10000  escuela      N
#
#          variable value actividad
# 6         act_dba     Y       dba
# 9         act_dba     Y       dba
# 11        act_dba     Y       dba
# 16        act_dba     Y       dba
# 17        act_dba     Y       dba
# ...           ...   ...       ...
# 33027  act_ventas     Y    ventas
# 33057  act_ventas     Y    ventas
# 33063  act_ventas     Y    ventas
# 33114  act_ventas     Y    ventas
# 33303  act_ventas     Y    ventas
#
# [3672 rows x 9 columns]

# %%
reader
# Out:
#           key                                               name
# 0         dba                   Administración de bases de datos
# 1         req                         Análisis de requerimientos
# 2         arq                  Arquitectura y diseño de sistemas
# 3          bi                              Business Intelligence
# 4         cap                      Capacitación y evangelización
# 5         dsc                                   Ciencia de datos
# 6      devops        Gestión de infraestructura (SysOps, DevOps)
# 7        deng                                Ingeniería de datos
# 8         spi                      Coaching y mejora de procesos
# 9        cons                             Consultoría de negocio
# 10        dir                             Dirección / Estrategia
# 11        doc                                           Docencia
# 12        uxd                             User Experience Design
# 13        erp  Implantación de sistemas empresariales (ERPs y...
# 14       prog  Programación back-end (procesamiento, lógica, ...
# 15      front                             Programación front-end
# 16         pm                  Project management / Coordinación
# 17  techsales                              Preventa / Tech sales
# 18    infosec                           Seguridad de información
# 19    soporte                                    Soporte técnico
# 20       test                                            Testing
# 21     ventas                     Venta y desarrollo de negocios
# 22  techwrite                  Documentación / Technical writing

# %%
df_new=pd.merge(DFact, reader, how='left', left_on='actividad', right_on='key')

# %%
df_new
# Out:
#       gender        profile    education  salarymx  edutype remote  \
# 0      mujer          godin      pasante      9000  escuela      N
# 1     hombre  independiente  universidad      4000  escuela      N
# 2     hombre          godin     maestria     45000  escuela      N
# 3     hombre          godin  universidad     25914  escuela      N
# 4     hombre          godin  universidad     25000  escuela      N
# ...      ...            ...          ...       ...      ...    ...
# 3667  hombre      directivo     posgrado     70000  escuela      N
# 3668   mujer          godin  universidad     30000  trabajo      N
# 3669  hombre    emprendedor  universidad     80000  escuela      N
# 3670  hombre      directivo     maestria     55000  escuela      N
# 3671  hombre     estudiante      tecnica     10000  escuela      N
#
#         variable value actividad     key                              name
# 0        act_dba     Y       dba     dba  Administración de bases de datos
# 1        act_dba     Y       dba     dba  Administración de bases de datos
# 2        act_dba     Y       dba     dba  Administración de bases de datos
# 3        act_dba     Y       dba     dba  Administración de bases de datos
# 4        act_dba     Y       dba     dba  Administración de bases de datos
# ...          ...   ...       ...     ...                               ...
# 3667  act_ventas     Y    ventas  ventas    Venta y desarrollo de negocios
# 3668  act_ventas     Y    ventas  ventas    Venta y desarrollo de negocios
# 3669  act_ventas     Y    ventas  ventas    Venta y desarrollo de negocios
# 3670  act_ventas     Y    ventas  ventas    Venta y desarrollo de negocios
# 3671  act_ventas     Y    ventas  ventas    Venta y desarrollo de negocios
#
# [3672 rows x 11 columns]

# %%
df_n=df_new.groupby(['profile','name','gender','education','edutype','remote'])['salarymx'].mean().reset_index()

# %%
df_n
# Out:
#         profile                              name  gender    education  \
# 0     directivo  Administración de bases de datos  hombre  universidad
# 1     directivo        Análisis de requerimientos  hombre     maestria
# 2     directivo        Análisis de requerimientos  hombre     maestria
# 3     directivo        Análisis de requerimientos  hombre      pasante
# 4     directivo        Análisis de requerimientos  hombre      pasante
# ...         ...                               ...     ...          ...
# 1246       otro                   Soporte técnico  hombre   secundaria
# 1247       otro                   Soporte técnico  hombre  universidad
# 1248       otro                           Testing  hombre  universidad
# 1249       otro                           Testing   mujer     maestria
# 1250       otro                           Testing   mujer      pasante
#
#           edutype remote  salarymx
# 0     autodidacta      N   50000.0
# 1         escuela      N   80330.0
# 2         trabajo      N   47000.0
# 3         escuela      N   60000.0
# 4         trabajo      N   18000.0
# ...           ...    ...       ...
# 1246      trabajo      Y   70000.0
# 1247     bootcamp      N   18000.0
# 1248  autodidacta      Y   23000.0
# 1249      escuela      N   25000.0
# 1250      escuela      Y   18009.0
#
# [1251 rows x 7 columns]

# %%
new_list=[]
nl=()
new_list=df_new.groupby(['name'])['salarymx'].mean().reset_index().sort_values(by=['salarymx'],ascending=False).head(10)
nl=new_list.name.unique()

# %%
nl
# Out:
# array(['Dirección / Estrategia', 'Preventa / Tech sales',
#        'Arquitectura y diseño de sistemas',
#        'Gestión de infraestructura (SysOps, DevOps)',
#        'Coaching y mejora de procesos', 'Ingeniería de datos',
#        'Project management / Coordinación', 'Ciencia de datos',
#        'Consultoría de negocio', 'Venta y desarrollo de negocios'],
#       dtype=object)

# %%
top_df=df_n.loc[df_n['name'].apply(lambda x: x in nl)]

# %%
top_df
# Out:
#         profile                               name  gender    education  \
# 11    directivo  Arquitectura y diseño de sistemas  hombre     maestria
# 12    directivo  Arquitectura y diseño de sistemas  hombre     maestria
# 13    directivo  Arquitectura y diseño de sistemas  hombre     maestria
# 14    directivo  Arquitectura y diseño de sistemas  hombre     maestria
# 15    directivo  Arquitectura y diseño de sistemas  hombre     maestria
# ...         ...                                ...     ...          ...
# 1219       otro              Preventa / Tech sales  hombre     maestria
# 1238       otro  Project management / Coordinación  hombre     maestria
# 1239       otro  Project management / Coordinación  hombre     maestria
# 1240       otro  Project management / Coordinación   mujer  universidad
# 1241       otro  Project management / Coordinación   mujer  universidad
#
#           edutype remote  salarymx
# 11    autodidacta      N   46500.0
# 12    autodidacta      Y   58000.0
# 13        escuela      N   60000.0
# 14        escuela      Y   90000.0
# 15        trabajo      N  100000.0
# ...           ...    ...       ...
# 1219  autodidacta      N  103000.0
# 1238  autodidacta      N   91500.0
# 1239       online      N   43043.0
# 1240      escuela      N    4000.0
# 1241      trabajo      N   27000.0
#
# [506 rows x 7 columns]

# %%
cross=pd.crosstab(top_df['name'], top_df['profile'])
cross
# Out:
# profile                                      directivo  docente  emprendedor  \
# name
# Arquitectura y diseño de sistemas                   13        3           11
# Ciencia de datos                                     2        3            0
# Coaching y mejora de procesos                       15        4            4
# Consultoría de negocio                              10        1            5
# Dirección / Estrategia                              22        0            4
# Gestión de infraestructura (SysOps, DevOps)          5        1            6
# Ingeniería de datos                                  3        2            1
# Preventa / Tech sales                                3        0            4
# Project management / Coordinación                   21        3            6
# Venta y desarrollo de negocios                       6        0            4
#
# profile                                      estudiante  godin  independiente  \
# name
# Arquitectura y diseño de sistemas                     1     57              9
# Ciencia de datos                                      1     24              3
# Coaching y mejora de procesos                         1     31              2
# Consultoría de negocio                                0     25              0
# Dirección / Estrategia                                0     23              2
# Gestión de infraestructura (SysOps, DevOps)           0     36              1
# Ingeniería de datos                                   2     32              2
# Preventa / Tech sales                                 0      6              1
# Project management / Coordinación                     1     45              1
# Venta y desarrollo de negocios                        1      8              0
#
# profile                                      otro
# name
# Arquitectura y diseño de sistemas              10
# Ciencia de datos                                2
# Coaching y mejora de procesos                   3
# Consultoría de negocio                          4
# Dirección / Estrategia                          3
# Gestión de infraestructura (SysOps, DevOps)     2
# Ingeniería de datos                             0
# Preventa / Tech sales                           1
# Project management / Coordinación               4
# Venta y desarrollo de negocios                  0

# %%
dis_profile_activity = round(cross.div(cross.sum(axis=1), axis=0)*100,2)
dis_profile_activity
# Out:
# profile                                      directivo  docente  emprendedor  \
# name
# Arquitectura y diseño de sistemas                12.50     2.88        10.58
# Ciencia de datos                                  5.71     8.57         0.00
# Coaching y mejora de procesos                    25.00     6.67         6.67
# Consultoría de negocio                           22.22     2.22        11.11
# Dirección / Estrategia                           40.74     0.00         7.41
# Gestión de infraestructura (SysOps, DevOps)       9.80     1.96        11.76
# Ingeniería de datos                               7.14     4.76         2.38
# Preventa / Tech sales                            20.00     0.00        26.67
# Project management / Coordinación                25.93     3.70         7.41
# Venta y desarrollo de negocios                   31.58     0.00        21.05
#
# profile                                      estudiante  godin  independiente  \
# name
# Arquitectura y diseño de sistemas                  0.96  54.81           8.65
# Ciencia de datos                                   2.86  68.57           8.57
# Coaching y mejora de procesos                      1.67  51.67           3.33
# Consultoría de negocio                             0.00  55.56           0.00
# Dirección / Estrategia                             0.00  42.59           3.70
# Gestión de infraestructura (SysOps, DevOps)        0.00  70.59           1.96
# Ingeniería de datos                                4.76  76.19           4.76
# Preventa / Tech sales                              0.00  40.00           6.67
# Project management / Coordinación                  1.23  55.56           1.23
# Venta y desarrollo de negocios                     5.26  42.11           0.00
#
# profile                                      otro
# name
# Arquitectura y diseño de sistemas            9.62
# Ciencia de datos                             5.71
# Coaching y mejora de procesos                5.00
# Consultoría de negocio                       8.89
# Dirección / Estrategia                       5.56
# Gestión de infraestructura (SysOps, DevOps)  3.92
# Ingeniería de datos                          0.00
# Preventa / Tech sales                        6.67
# Project management / Coordinación            4.94
# Venta y desarrollo de negocios               0.00

# %%
plt_prop = dis_profile_activity.plot(kind='bar', stacked = True, width = 1)#,colormap='plasma')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('Porcentaje de actividad por perfil de puesto', fontsize=18)
_ = plt.xlabel('Perfil de Puesto', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
crosse=pd.crosstab(top_df['name'], top_df['education'])
crosse
# Out:
# education                                    maestria  pasante  phd  posgrado  \
# name
# Arquitectura y diseño de sistemas                  24       22    5         9
# Ciencia de datos                                   12        8    5         2
# Coaching y mejora de procesos                      18       12    1        10
# Consultoría de negocio                              9        8    2         5
# Dirección / Estrategia                             13       11    1         8
# Gestión de infraestructura (SysOps, DevOps)        10       14    1         1
# Ingeniería de datos                                 8       13    3         2
# Preventa / Tech sales                               6        3    0         3
# Project management / Coordinación                  23       18    1        11
# Venta y desarrollo de negocios                      3        2    0         5
#
# education                                    prepa  secundaria  tecnica  \
# name
# Arquitectura y diseño de sistemas                6           0        3
# Ciencia de datos                                 0           0        0
# Coaching y mejora de procesos                    1           1        0
# Consultoría de negocio                           0           0        2
# Dirección / Estrategia                           1           1        0
# Gestión de infraestructura (SysOps, DevOps)      6           0        3
# Ingeniería de datos                              0           0        2
# Preventa / Tech sales                            0           0        0
# Project management / Coordinación                1           0        2
# Venta y desarrollo de negocios                   0           0        1
#
# education                                    universidad
# name
# Arquitectura y diseño de sistemas                     35
# Ciencia de datos                                       8
# Coaching y mejora de procesos                         17
# Consultoría de negocio                                19
# Dirección / Estrategia                                19
# Gestión de infraestructura (SysOps, DevOps)           16
# Ingeniería de datos                                   14
# Preventa / Tech sales                                  3
# Project management / Coordinación                     25
# Venta y desarrollo de negocios                         8

# %%
act_e = round(crosse.div(crosse.sum(axis=1), axis=0)*100,2)
act_e
# Out:
# education                                    maestria  pasante    phd  \
# name
# Arquitectura y diseño de sistemas               23.08    21.15   4.81
# Ciencia de datos                                34.29    22.86  14.29
# Coaching y mejora de procesos                   30.00    20.00   1.67
# Consultoría de negocio                          20.00    17.78   4.44
# Dirección / Estrategia                          24.07    20.37   1.85
# Gestión de infraestructura (SysOps, DevOps)     19.61    27.45   1.96
# Ingeniería de datos                             19.05    30.95   7.14
# Preventa / Tech sales                           40.00    20.00   0.00
# Project management / Coordinación               28.40    22.22   1.23
# Venta y desarrollo de negocios                  15.79    10.53   0.00
#
# education                                    posgrado  prepa  secundaria  \
# name
# Arquitectura y diseño de sistemas                8.65   5.77        0.00
# Ciencia de datos                                 5.71   0.00        0.00
# Coaching y mejora de procesos                   16.67   1.67        1.67
# Consultoría de negocio                          11.11   0.00        0.00
# Dirección / Estrategia                          14.81   1.85        1.85
# Gestión de infraestructura (SysOps, DevOps)      1.96  11.76        0.00
# Ingeniería de datos                              4.76   0.00        0.00
# Preventa / Tech sales                           20.00   0.00        0.00
# Project management / Coordinación               13.58   1.23        0.00
# Venta y desarrollo de negocios                  26.32   0.00        0.00
#
# education                                    tecnica  universidad
# name
# Arquitectura y diseño de sistemas               2.88        33.65
# Ciencia de datos                                0.00        22.86
# Coaching y mejora de procesos                   0.00        28.33
# Consultoría de negocio                          4.44        42.22
# Dirección / Estrategia                          0.00        35.19
# Gestión de infraestructura (SysOps, DevOps)     5.88        31.37
# Ingeniería de datos                             4.76        33.33
# Preventa / Tech sales                           0.00        20.00
# Project management / Coordinación               2.47        30.86
# Venta y desarrollo de negocios                  5.26        42.11

# %%
plt_prop = act_e.plot(kind='bar', stacked = True, width = 1)#,colormap='plasma')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('La actividad es independiente de la educación', fontsize=18)
_ = plt.xlabel('Actividad', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
g, p, dof, expctd = chi2_contingency(crosse)
print("Valor P de  Chi cuadrada entre puesto y educacion =", p)
# Out:
# Valor P de  Chi cuadrada entre puesto y educacion = 0.05017129585151327

# %%
crosse=pd.crosstab(df1['profile'], df1['education'])
act_e = round(crosse.div(crosse.sum(axis=1), axis=0)*100,2)
plt_prop = act_e.plot(kind='bar', stacked = True, width = 1)#,colormap='plasma')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('El perfil no es independiente del tipo de educación', fontsize=18)
_ = plt.xlabel('Perfil de Puesto ', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
g, p, dof, expctd = chi2_contingency(crosse)
print("Valor P de  Chi cuadrada entre perfil y educacion =", p)
# Out:
# Valor P de  Chi cuadrada entre perfil y educacion = 5.91265496053453e-47

# %%
df_new_t=df_new.loc[df_new['name'].apply(lambda x: x in nl)]
plt.figure(figsize=(15,6))
sns.stripplot(x='name',y='salarymx', palette="plasma",hue='profile'
            ,data=df_new_t)
plt.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.title('Salario por activiad', fontsize=16)
_ = plt.xlabel('Actividad', fontsize=16)
_ = plt.ylabel('Salario en Pesos', fontsize=16)
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
df_new_t=df_new.loc[df_new['name'].apply(lambda x: x in nl)]
plt.figure(figsize=(15,6))
sns.stripplot(x='edutype',y='salarymx', palette="plasma",hue='profile'
            ,data=df_new_t)
plt.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.title('Salario por activiad', fontsize=16)
_ = plt.xlabel('Actividad', fontsize=16)
_ = plt.ylabel('Salario en Pesos', fontsize=16)
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='profile',y='salarymx', palette = 'YlGnBu',hue='remote'
            ,data=df1)
plt.title('Remoto - Cliente Internacional - Valores mas altos de Salario', fontsize=16)
_ = plt.xlabel('Perfil de puesto', fontsize=16)
_ = plt.ylabel('Salario en Pesos', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='name',y='salarymx', palette = 'YlGnBu',hue='remote'
            ,data=df_new_t)
plt.title('Remoto - Cliente Internacional - Valores mas altos de Salario', fontsize=16)
_ = plt.xlabel('Perfil de puesto', fontsize=16)
_ = plt.ylabel('Salario en Pesos', fontsize=16)
plt.show()

# %%
crosse=pd.crosstab(df1['profile'], df1['remote'])
act_e = round(crosse.div(crosse.sum(axis=1), axis=0)*100,2)
plt_prop = act_e.plot(kind='bar', stacked = True, width = 1)#,colormap='plasma')
plt_prop.legend(bbox_to_anchor=(1,1), loc='upper left', ncol = 1)
plt.xticks(rotation=60, ha='right')
_ = plt.title('El perfil no es independiente de el tipo de educación', fontsize=18)
_ = plt.xlabel('Perfil de Puesto ', fontsize=18)
_ = plt.ylabel("%", fontsize=18)

# %%
df1.columns
# Out:
# Index(['remote', 'salarymx', 'age', 'experience', 'seniority', 'emptype',
#        'gender', 'edutype', 'english_label', 'city', 'profile', 'orgtype',
#        'education', 'covid_salario', 'covid_carga', 'covid_apoyo'],
#       dtype='object')

# %%
df1['covid_salario'].unique()
# Out:
# array([nan, 'igual', 'mejor', 'desempleo', 'bajatemp', 'bajaperm'],
#       dtype=object)

# %%
df1['covid_carga'].unique()
# Out:
# array([nan, 'aumentado', 'disminuido', 'Igual'], dtype=object)

# %%
df1['covid_apoyo'].unique()
# Out:
# array([nan, 'computadora', "['computadora', 'muebles']",
#        "['computadora', 'muebles', 'internet']", 'internet',
#        "['computadora', 'internet']", 'muebles',
#        "['muebles', 'internet']"], dtype=object)

# %%
df1['covid_salario'].value_counts()
# Out:
# igual        1018
# mejor         302
# bajatemp      138
# bajaperm       82
# desempleo      77
# Name: covid_salario, dtype: int64

# %%
plt.figure(figsize=(15,6))
pl = sns.countplot(x="covid_salario", hue='covid_carga',data= df1, palette='YlGnBu')
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title("La mayoria no tuvo un cambio de salario o mejoro \n pero la carga de trabajo aumento", fontsize=20, verticalalignment='bottom');
_ = plt.xlabel('Cambio de Salario ', fontsize=18)
_ = plt.ylabel("Numero de Encuestado", fontsize=18)

# %%
pl = sns.countplot(x="covid_carga", data= df1, palette='YlGnBu')
pl.set_xticklabels(pl.get_xticklabels(), rotation=40, ha="right");
plt.title("La mayoria no tuvo un cambio de salario o mejoro", fontsize=20, verticalalignment='bottom');
_ = plt.xlabel('Cambio en la carga de trabajo ', fontsize=18)
_ = plt.ylabel("Numero de Encuestado", fontsize=18)

# %%
df1.covid_apoyo.value_counts()
# Out:
# computadora                               693
# ['computadora', 'muebles']                246
# ['computadora', 'muebles', 'internet']     51
# ['computadora', 'internet']                46
# internet                                   30
# muebles                                    28
# ['muebles', 'internet']                     2
# Name: covid_apoyo, dtype: int64
